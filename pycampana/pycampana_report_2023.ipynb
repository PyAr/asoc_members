# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from collections import Counter

# %%
fname = "PyCampAna 2023 (Responses) - Form Responses 1.csv"
df = pd.read_csv(fname)

# %%
def word_c(col_name, replacements={}, exclude=[], show_counter=False):
    col = df[col_name].fillna("").str.strip().str.lower()
    if replacements:
        for k,v in replacements.items():
            col = col.str.replace(k,v)
    show_counter and print(col.value_counts())
    words_count = Counter(map(str.strip, (col.str.cat(sep=",").split(","))))
    all_words = col.str.cat(sep=" ")
    stopwords = STOPWORDS.union(["de", "el", "del", "la", "en", "las", "que", "y", "muy", "un"])
    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords.union(exclude),
                min_font_size = 10).generate(all_words)

    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()

# %% [markdown]
# # Promedios

# %% [markdown]
# * ¿Cuántos kilómetros hiciste para llegar?              **808.833333**
# * ¿Cuántas veces te bañaste?                              **3.525000**
# * ¿A cuántos PyCamp fuiste? (contando el actual)?         **3.384615**
# * ¿En cuántos proyectos participaste en este PyCamp?      **2.100000**
# * ¿Qué nota le pondrías a la comida?                      **8.600000**
# * ¿Qué nota le pondrías a los dormitorios?                **7.250000**
# * ¿Qué nota le pondrías a Internet?                       **4.125000**
# * ¿Qué nota le pondrías al lugar?                         **8.450000**
# * Tu edad                                                **32.075000**
# * ¿Tenés hijes?                                           **0.450000**

# %% [markdown]
# # Dónde debería ser el próximo PyCamp

# %%
word_c(
    '¿Dónde te gustaría que se haga un PyCamp?', 
   replacements={'cordoba': "córdoba", 'jesús mario': "jesus maria"}
)

# %% [markdown]
# # Nivel de manejo de Python de los PyCampistas

# %%
word_c(
    '¿Cómo describirías tu nivel de manejo de Python?', 
    replacements={"basico":"básico", "avanzaso":"avanzado"}, 
    exclude=["si", "sin", "al", ]
)

# %% [markdown]
# # Feedback

# %%
word_c("¿Querés dejar algún otro feedback?", replacements={"ek":"el"}, exclude=["es", "les", "por", "si", "los", "las", "para", "ya", "con"])

# %% [markdown]
# # Místico

# %% [markdown]
# # ¿Cuánto se bañan por cada signo?
# * Acuario        **2.5**
# * Aries          **4.0**
# * Capricornio    **3.6**
# * Cáncer         **5.0**
# * Escorpión      **4.0**
# * Géminis        **3.75**
# * Leo            **4.0**
# * Libra          **2.0**
# * Piscis         **5.5**
# * Sagitario      **3.0**
# * Tauro          **2.8**
# * Virgo          **3.83**

# %% [markdown]
# * Fuerte influencia de *Cancer* en la comunidad
# * Hay que trabajar en términos de inclusión (astral) para aumentar el federalismo astral de Aries y Leo
# * Los de Cáncer y los Virgo usan mucho Python en el laburo, pero los de Escorpio nada
# * Los de Libra podrían revisar sus desiciones higiénicas
# * Dragones, Serpientes y Tigres programando mucho Python (atenti para recruiting)
